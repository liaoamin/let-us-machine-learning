# %% [markdown]
# ## 零基础实战机器学习
#
# ## 第12讲 RNN预测App的激活数走势
#
# 作者 黄佳
#
# 极客时间专栏链接：https://time.geekbang.org/column/intro/438
#
#
# 问题：根据App的历史激活（即下载后注册用户并使用App）数字，来预测其未来走势
#
# 易速鲜花公司拥有过去两年App的日激活数。
#
# 通过神经网络中的RNN模型，我们可以对这个时序数据集进行预测。

# %% [markdown]
# ## 数据的读入和预处理

# %%
import numpy as np #导入NumPy
import pandas as pd #导入Pandas

# %%
df_app = pd.read_csv('app.csv', index_col='Date', parse_dates=['Date']) #导入数据
df_app #显示数据
print(df_app.index)
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2021-01-16', '2021-01-17', '2021-01-18', '2021-01-19',
#                '2021-01-20', '2021-01-21', '2021-01-22', '2021-01-23',
#                '2021-01-24', '2021-01-25'],
#               dtype='datetime64[ns]', name='Date', length=756, freq=None)

# %%
import matplotlib.pyplot as plt #导入matplotlib.pyplot
plt.style.use('fivethirtyeight') #设定绘图风格
df_app["Activation"].plot(figsize=(12,4),legend=True) #绘制激活数
plt.title('App Activation Count') #图题
plt.show() #绘图

# %% [markdown]
# ### 数据清洗

# %%
df_app.isna().sum() #有NaN吗？
# Out:
# Activation    0
# dtype: int64

# %%
(df_app.Activation < 0).values.any() #有负值吗？
# Out:
# False

# %% [markdown]
# ### 拆分数据集

# %%
# 按照2020年10月1日为界拆分数据集
Train = df_app[:'2020-09-30'].iloc[:,0:1].values #训练集
Test = df_app['2020-10-01':].iloc[:,0:1].values #测试集

# %%
Train
# Out:
# array([[419],
#        [432],
#        [436],
#        [439],
#        [439],
#        [435],
#        [423],
#        [428],
#        [421],
#        [418],
#        [423],
#        [424],
#        [431],
#        [449],
#        [442],
#        [449],
#        [459],
#        [464],
#        [468],
#        [461],
#        [453],
#        [455],
#        [469],
#        [461],
#        [463],
#        [480],
#        [478],
#        [467],
#        [472],
#        [474],
#        [459],
#        [456],
#        [455],
#        [440],
#        [447],
#        [423],
#        [430],
#        [434],
#        [441],
#        [456],
#        [451],
#        [445],
#        [441],
#        [437],
#        [424],
#        [426],
#        [438],
#        [443],
#        [452],
#        [458],
#        [456],
#        [447],
#        [464],
#        [466],
#        [469],
#        [488],
#        [492],
#        [492],
#        [480],
#        [460],
#        [475],
#        [481],
#        [496],
#        [499],
#        [505],
#        [501],
#        [497],
#        [510],
#        [501],
#        [495],
#        [491],
#        [499],
#        [506],
#        [501],
#        [492],
#        [506],
#        [513],
#        [506],
#        [498],
#        [497],
#        [510],
#        [523],
#        [519],
#        [526],
#        [530],
#        [526],
#        [523],
#        [518],
#        [505],
#        [515],
#        [514],
#        [509],
#        [505],
#        [510],
#        [522],
#        [528],
#        [515],
#        [513],
#        [507],
#        [522],
#        [517],
#        [522],
#        [535],
#        [538],
#        [533],
#        [531],
#        [537],
#        [533],
#        [541],
#        [546],
#        [544],
#        [542],
#        [538],
#        [542],
#        [537],
#        [535],
#        [532],
#        [526],
#        [524],
#        [527],
#        [519],
#        [533],
#        [530],
#        [528],
#        [525],
#        [519],
#        [508],
#        [507],
#        [501],
#        [506],
#        [505],
#        [506],
#        [517],
#        [524],
#        [534],
#        [567],
#        [573],
#        [579],
#        [581],
#        [575],
#        [583],
#        [585],
#        [583],
#        [582],
#        [590],
#        [588],
#        [594],
#        [596],
#        [593],
#        [592],
#        [591],
#        [591],
#        [590],
#        [588],
#        [596],
#        [596],
#        [583],
#        [584],
#        [582],
#        [592],
#        [598],
#        [600],
#        [596],
#        [593],
#        [594],
#        [601],
#        [586],
#        [588],
#        [582],
#        [583],
#        [583],
#        [590],
#        [585],
#        [585],
#        [589],
#        [585],
#        [594],
#        [598],
#        [606],
#        [612],
#        [605],
#        [610],
#        [606],
#        [603],
#        [601],
#        [603],
#        [597],
#        [596],
#        [597],
#        [587],
#        [595],
#        [602],
#        [606],
#        [613],
#        [612],
#        [627],
#        [631],
#        [639],
#        [638],
#        [616],
#        [609],
#        [617],
#        [611],
#        [604],
#        [615],
#        [603],
#        [601],
#        [602],
#        [611],
#        [613],
#        [604],
#        [598],
#        [607],
#        [611],
#        [613],
#        [620],
#        [627],
#        [633],
#        [633],
#        [632],
#        [636],
#        [637],
#        [640],
#        [636],
#        [636],
#        [639],
#        [640],
#        [639],
#        [623],
#        [626],
#        [636],
#        [637],
#        [638],
#        [642],
#        [634],
#        [635],
#        [634],
#        [641],
#        [645],
#        [648],
#        [647],
#        [644],
#        [640],
#        [640],
#        [639],
#        [647],
#        [649],
#        [649],
#        [655],
#        [661],
#        [656],
#        [662],
#        [656],
#        [658],
#        [653],
#        [649],
#        [645],
#        [655],
#        [645],
#        [652],
#        [653],
#        [660],
#        [658],
#        [652],
#        [652],
#        [643],
#        [632],
#        [630],
#        [629],
#        [635],
#        [622],
#        [616],
#        [624],
#        [626],
#        [626],
#        [615],
#        [616],
#        [613],
#        [615],
#        [613],
#        [615],
#        [625],
#        [628],
#        [631],
#        [637],
#        [637],
#        [632],
#        [635],
#        [630],
#        [635],
#        [638],
#        [644],
#        [639],
#        [635],
#        [636],
#        [635],
#        [631],
#        [630],
#        [629],
#        [640],
#        [637],
#        [640],
#        [645],
#        [637],
#        [644],
#        [636],
#        [640],
#        [643],
#        [647],
#        [645],
#        [647],
#        [645],
#        [641],
#        [645],
#        [642],
#        [643],
#        [643],
#        [640],
#        [639],
#        [643],
#        [641],
#        [649],
#        [653],
#        [653],
#        [652],
#        [646],
#        [649],
#        [643],
#        [645],
#        [649],
#        [650],
#        [647],
#        [653],
#        [652],
#        [647],
#        [644],
#        [636],
#        [631],
#        [617],
#        [631],
#        [626],
#        [636],
#        [655],
#        [655],
#        [653],
#        [656],
#        [647],
#        [636],
#        [611],
#        [626],
#        [607],
#        [624],
#        [625],
#        [630],
#        [623],
#        [624],
#        [639],
#        [632],
#        [628],
#        [621],
#        [624],
#        [630],
#        [634],
#        [643],
#        [645],
#        [642],
#        [650],
#        [655],
#        [657],
#        [652],
#        [646],
#        [648],
#        [642],
#        [638],
#        [637],
#        [624],
#        [618],
#        [616],
#        [618],
#        [617],
#        [637],
#        [640],
#        [637],
#        [645],
#        [647],
#        [649],
#        [650],
#        [643],
#        [615],
#        [632],
#        [632],
#        [637],
#        [641],
#        [644],
#        [643],
#        [645],
#        [637],
#        [646],
#        [650],
#        [652],
#        [654],
#        [652],
#        [654],
#        [656],
#        [653],
#        [638],
#        [640],
#        [637],
#        [644],
#        [644],
#        [643],
#        [644],
#        [638],
#        [626],
#        [623],
#        [629],
#        [619],
#        [625],
#        [617],
#        [627],
#        [630],
#        [631],
#        [635],
#        [630],
#        [636],
#        [635],
#        [643],
#        [642],
#        [643],
#        [646],
#        [650],
#        [651],
#        [657],
#        [658],
#        [657],
#        [662],
#        [668],
#        [673],
#        [672],
#        [678],
#        [678],
#        [676],
#        [681],
#        [684],
#        [690],
#        [692],
#        [694],
#        [692],
#        [700],
#        [702],
#        [711],
#        [705],
#        [687],
#        [691],
#        [699],
#        [701],
#        [702],
#        [696],
#        [698],
#        [709],
#        [705],
#        [718],
#        [719],
#        [721],
#        [724],
#        [730],
#        [727],
#        [734],
#        [730],
#        [724],
#        [723],
#        [719],
#        [715],
#        [712],
#        [715],
#        [722],
#        [720],
#        [721],
#        [720],
#        [727],
#        [718],
#        [711],
#        [718],
#        [722],
#        [721],
#        [723],
#        [730],
#        [722],
#        [730],
#        [724],
#        [726],
#        [721],
#        [726],
#        [724],
#        [723],
#        [727],
#        [725],
#        [728],
#        [729],
#        [726],
#        [727],
#        [730],
#        [732],
#        [734],
#        [736],
#        [738],
#        [737],
#        [736],
#        [744],
#        [738],
#        [741],
#        [740],
#        [746],
#        [744],
#        [749],
#        [766],
#        [773],
#        [782],
#        [777],
#        [796],
#        [808],
#        [807],
#        [805],
#        [796],
#        [811],
#        [817],
#        [816],
#        [817],
#        [820],
#        [824],
#        [828],
#        [820],
#        [820],
#        [821],
#        [814],
#        [817],
#        [817],
#        [822],
#        [818],
#        [809],
#        [798],
#        [805],
#        [812],
#        [816],
#        [797],
#        [807],
#        [817],
#        [808],
#        [799],
#        [817],
#        [823],
#        [812],
#        [806],
#        [787],
#        [783],
#        [770],
#        [783],
#        [788],
#        [793],
#        [790],
#        [801],
#        [805],
#        [808],
#        [807],
#        [818],
#        [817],
#        [819],
#        [822],
#        [819],
#        [822],
#        [821],
#        [822],
#        [817],
#        [817],
#        [820],
#        [819],
#        [825],
#        [823],
#        [829],
#        [816],
#        [828],
#        [838],
#        [840],
#        [843],
#        [850],
#        [856],
#        [861],
#        [860],
#        [862],
#        [852],
#        [845],
#        [842],
#        [846],
#        [852],
#        [848],
#        [859],
#        [849],
#        [839],
#        [851],
#        [854],
#        [852],
#        [843],
#        [843],
#        [838],
#        [837],
#        [840],
#        [842],
#        [845],
#        [832],
#        [822],
#        [824],
#        [826],
#        [816],
#        [825],
#        [823],
#        [822],
#        [819],
#        [814],
#        [810],
#        [821],
#        [819],
#        [826],
#        [828],
#        [820],
#        [829],
#        [829],
#        [842],
#        [853],
#        [856],
#        [858],
#        [868],
#        [876],
#        [884],
#        [877],
#        [875],
#        [875],
#        [875],
#        [872],
#        [875]], dtype=int64)

# %%
print('训练集的形状是：', Train.shape)
print('测试集的形状是：', Test.shape)
# Out:
# 训练集的形状是： (639, 1)
# 测试集的形状是： (117, 1)

# %%
# 以不同颜色为训练集和测试集绘图
df_app["Activation"][:'2020-09-30'].plot(figsize=(12,4),legend=True) #训练集
df_app["Activation"]['2020-10-01':].plot(figsize=(12,4),legend=True) #测试集
plt.legend(['Training set (Before October 2020)','Test set (2020 October and beyond)']) #图例
plt.title('App Activation Count') #图题
plt.show() #绘图

# %% [markdown]
# ### 特征工程

# %%
from sklearn.preprocessing import MinMaxScaler #导入归一化缩放器
Scaler = MinMaxScaler(feature_range=(0,1)) #创建缩放器
Train = Scaler.fit_transform(Train) #拟合缩放器并对训练集进行归一化

# %%
print(type(Train))
print(Train[1:3,0])
# Out:
# <class 'numpy.ndarray'>
# [0.03004292 0.03862661]

# %% [markdown]
# ### 构建特征集和标签集

# %%
# 创建具有 60 个时间步长和 1 个输出的数据结构 - 训练集
X_train = [] #初始化
y_train = [] #初始化
for i in range(60,Train.size): 
    X_train.append(Train[i-60:i,0]) #构建特征
    y_train.append(Train[i,0]) #构建标签
X_train, y_train = np.array(X_train), np.array(y_train) #转换为NumPy数组
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1)) #转换成神经网络所需的张量形状
print(X_train.shape)
print(y_train.shape)
# Out:
# (579, 60, 1)
# (579,)

# %%
TrainTest = df_app["Activation"][:] #整体数据
print(type(df_app), type(df_app["Activation"]), type(df_app["Activation"].iloc[:]))
print(TrainTest.head())
inputs = TrainTest[len(TrainTest)-len(Test) - 60:].values #Test加上前60个时间步
inputs = inputs.reshape(-1,1) #转换形状
inputs  = Scaler.transform(inputs) #归一化
# 创建具有 60 个时间步长和 1 个输出的数据结构 - 测试集
X_test = [] #初始化
y_test = [] #初始化
for i in range(60,inputs.size): 
    X_test.append(inputs[i-60:i,0]) #构建特征
    y_test.append(inputs[i,0]) #构建标签
X_test = np.array(X_test) #转换为NumPy数组
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1)) #转换成神经网络所需的张量形状
print(X_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>
# Date
# 2019-01-01    419
# 2019-01-02    432
# 2019-01-03    436
# 2019-01-04    439
# 2019-01-05    439
# Name: Activation, dtype: int64
# (117, 60, 1)

# %% [markdown]
# ## 选择算法
#
# 这里我们采用RNN神经网络两种算法

# %% [markdown]
# ### 神经网络模型

# %%
#!pip install keras
#!pip install tensorflow

# %%
#from keras.models import Sequential #导入序贯模型
#from keras.layers import Dense, LSTM #导入全连接层和LSTM层
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
# from keras.optimizers import SGD
# LSTM网络架构
RNN_LSTM = Sequential() #序贯模型
RNN_LSTM.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1))) #输入层LSTM
RNN_LSTM.add(LSTM(units=50, return_sequences=True)) #中间1层LSTM
RNN_LSTM.add(LSTM(units=50, return_sequences=True)) #中间2层LSTM
RNN_LSTM.add(LSTM(units=50)) #中间3层LSTM
RNN_LSTM.add(Dense(units=1)) #输出层Dense
RNN_LSTM.compile(optimizer='rmsprop',loss='mean_squared_error') #编译网络
RNN_LSTM.summary() #输出神经网络结构信息
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 # from keras.optimizers import SGD
#       6 # LSTM网络架构
#       7 RNN_LSTM = Sequential() #序贯模型
# ----> 8 RNN_LSTM.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1))) #输入层LSTM
#       9 RNN_LSTM.add(LSTM(units=50, return_sequences=True)) #中间1层LSTM
#      10 RNN_LSTM.add(LSTM(units=50, return_sequences=True)) #中间2层LSTM
#
# NameError: name 'X_train' is not defined

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import sys
print("Python 解释器路径:", sys.executable)
import os
print("PATH 环境变量:")
print(os.environ['PATH'])

# %%
# 训练并保存训练历史信息
history = RNN_LSTM.fit(X_train, y_train, # 指定训练集
                  epochs=50,        # 指定训练的轮次
                  batch_size=64,    # 指定数据批量
                  validation_split=0.2) #这里直接从训练集数据中拆分验证集，更方便
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.1084 - val_loss: 0.0516
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0041 - val_loss: 0.0087
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0109 - val_loss: 0.0049
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0093 - val_loss: 0.0061
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0101 - val_loss: 0.0091
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0053 - val_loss: 0.0441
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0092 - val_loss: 0.0547
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0052 - val_loss: 0.0817
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0097 - val_loss: 0.0043
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0054 - val_loss: 0.0033
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0076 - val_loss: 0.0035
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0064 - val_loss: 0.0098
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0048 - val_loss: 0.0084
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0048 - val_loss: 0.0209
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0044 - val_loss: 0.0215
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0027 - val_loss: 0.0560
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0065 - val_loss: 0.0028
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0065 - val_loss: 0.0091
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0042 - val_loss: 0.0027
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0037 - val_loss: 0.0151
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0027 - val_loss: 0.0431
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0036 - val_loss: 0.0373
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0042 - val_loss: 0.0213
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0033 - val_loss: 0.0434
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0047 - val_loss: 0.0571
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0060 - val_loss: 0.0262
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0052 - val_loss: 0.0290
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0028 - val_loss: 0.0497
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0045 - val_loss: 0.0138
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0025 - val_loss: 0.0351
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0041 - val_loss: 0.0247
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0036 - val_loss: 0.0254
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0031 - val_loss: 0.0214
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0037 - val_loss: 0.0216
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0036 - val_loss: 0.0089

# %%
def show_history(history): # 显示训练过程中的学习曲线
    loss = history.history['loss'] #训练损失
    val_loss = history.history['val_loss'] #验证损失
    epochs = range(1, len(loss) + 1) #训练轮次
    plt.figure(figsize=(12,4)) # 图片大小
    plt.subplot(1, 2, 1) #子图1
    plt.plot(epochs, loss, 'bo', label='Training loss') #训练损失
    plt.plot(epochs, val_loss, 'b', label='Validation loss') #验证损失
    plt.title('Training and validation loss') #图题
    plt.xlabel('Epochs') #X轴文字
    plt.ylabel('Loss') #Y轴文字
    plt.legend() #图例
    plt.show() #绘图

# %%
show_history(history) # 调用绘图函数

# %%
# 定义绘图函数
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real Count') #真值
    plt.plot(predicted, color='blue',label='Predicted Count') #预测值
    plt.title('Flower App Activation Prediction') #图题
    plt.xlabel('Time') #X轴时间
    plt.ylabel('Flower App Activation Count') #Y轴激活数
    plt.legend() #图例
    plt.show() #绘图

# %%
y_pred = RNN_LSTM.predict(X_test) #预测
Pred = Scaler.inverse_transform(y_pred) #反归一化
plot_predictions(Test,Pred) #绘图
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step

# %%
import math #导入数学函数
from sklearn.metrics import mean_squared_error
def return_rmse(test,predicted): #定义均方损失函数
    rmse = math.sqrt(mean_squared_error(test, predicted)) #均方损失
    print("MSE损失值 {}.".format(rmse))

# %%
return_rmse(y_test,y_pred) #计算均方损失
# Out:
# MSE损失值 0.14264969184994108.
